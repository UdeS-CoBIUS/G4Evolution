# %%
import os
import pandas as pd
import seaborn as sns
from pprint import pprint
import matplotlib.pyplot as plt

# %% [markdown]
# # Import data for all species

# %%
# dfRBPpeaks = pd.DataFrame()
# directory = '/home/anais/Documents/Projet/G4RBPevo/data/POSTARTexcludedHuman/'
# for path, dirs, files in os.walk(directory):
#     for filename in files:
#         if 'Readme' not in filename:
#             inputfile = directory + '/' + filename
#             dfTmp = pd.read_csv(inputfile, sep='\t', index_col=0)
#             dfTmp['Species'] = filename.split('.')[0]
#             dfRBPpeaks = dfRBPpeaks.append(dfTmp)
# dfRBPpeaks

# %% [markdown]
# Well files are to heavy to be read at the same time, so I will do species after species.
# # Scer

# %%
directory = '/home/anais/Documents/Projet/G4RBPevo/data/POSTARTexcludedHuman/'
inputfile = directory + '/saccharomyces_cerevisiae.bed'
dfRBPpeaks = pd.read_csv(inputfile, sep='\t', names=['Chromosome', 'Start_BS', 'End_BS', 'Id_BS', 'Strand', 'RBP', 'Method', 'Sample_Tissue_cellLine', 'Accession'])
dfRBPpeaks
# Out:
#         Chromosome  Start_BS  End_BS                              Id_BS  \
# 0             chrI       691     708  yeast_RBP_CLIPdb_PAR-CLIP_2265426
# 1             chrI      7292    7312  yeast_RBP_CLIPdb_PAR-CLIP_2795826
# 2             chrI      7293    7319  yeast_RBP_CLIPdb_PAR-CLIP_2357011
# 3             chrI      7349    7371  yeast_RBP_CLIPdb_PAR-CLIP_2357013
# 4             chrI      7349    7390  yeast_RBP_CLIPdb_PAR-CLIP_2265468
# ...            ...       ...     ...                                ...
# 3388042     chrXVI    946249  946289    yeast_RBP_CLIPdb_PAR-CLIP_82787
# 3388043     chrXVI    946249  946290  yeast_RBP_CLIPdb_PAR-CLIP_4390695
# 3388044     chrXVI    946250  946289   yeast_RBP_CLIPdb_PAR-CLIP_379123
# 3388045     chrXVI    946250  946294  yeast_RBP_CLIPdb_PAR-CLIP_3578778
# 3388046     chrXVI    946250  946295  yeast_RBP_CLIPdb_PAR-CLIP_3546759
#
#         Strand   RBP              Method Sample_Tissue_cellLine  \
# ...

# %%
print('There are '+str(len(dfRBPpeaks[dfRBPpeaks.Strand == '+']))+' and '+str(len(dfRBPpeaks[dfRBPpeaks.Strand == '-']))+' binding site on the forward and reverse strand respectively. There are '+str(len(set(dfRBPpeaks['RBP'])))+' different RBPs detected on '+str(len(set(dfRBPpeaks['Sample_Tissue_cellLine'])))+' sample/tissue/cell lines and are '+'\n\t- '.join(list(set(dfRBPpeaks['Sample_Tissue_cellLine'])))+'\n These RBP were dected throught: '+'\n\t- '.join(list(set(dfRBPpeaks['Method']))))
# Out:
# There are 1693893 and 1694154 binding site on the forward and reverse strand respectively. There are 65 different RBPs detected on 2 sample/tissue/cell lines and are BY4741
# 	- YJC2671
#  These RBP were dected throught: HITS-CLIP,Piranha_0.01
# 	- HITS-CLIP,CIMS
# 	- PAR-CLIP,Piranha_0.01
# 	- HITS-CLIP,CTK
# 	- PAR-CLIP,PARalyzer
# 	- PAR-CLIP,MiClip

# %% [markdown]
# BY4741 -> MATa his3Δ1 leu2Δ0 met15Δ0 ura3Δ0
#
# YJC2671 -> ?

# %% [markdown]
# # Mmus

# %%
directory = '/home/anais/Documents/Projet/G4RBPevo/data/POSTARTexcludedHuman/'
inputfile = directory + '/mus_musculus.bed'
dfRBPpeaks = pd.read_csv(inputfile, sep='\t', names=['Chromosome', 'Start_BS', 'End_BS', 'Id_BS', 'Strand', 'RBP', 'Method', 'Sample_Tissue_cellLine', 'Accession'])
dfRBPpeaks
# Out:
#         Chromosome  Start_BS    End_BS                                  Id_BS  \
# 0             chr1   3102040   3102060                    Mouse_RBP_POSTAR3_3
# 1             chr1   3208396   3208397                   Mouse_RBP_POSTAR3_57
# 2             chr1   3209256   3209257                   Mouse_RBP_POSTAR3_58
# 3             chr1   3209298   3209319       mouse_RBP_CLIPdb_HITS-CLIP_14009
# 4             chr1   3213120   3213140                   Mouse_RBP_POSTAR3_59
# ...            ...       ...       ...                                    ...
# 2787398       chrY  90813600  90813601          mouse_RBP_CLIPdb_iCLIP_402413
# 2787399       chrY  90813600  90813620   mouse_RBP_CLIPdb_piranha0.01_1003968
# 2787400       chrY  90813919  90813940  mouse_RBP_CLIPdb_HITS-CLIP_CIMS_18274
# 2787401       chrY  90813940  90813960   mouse_RBP_CLIPdb_piranha0.01_1003969
# 2787402       chrY  90813940  90813960   mouse_RBP_CLIPdb_piranha0.01_1003970
#
# ...

# %%
print('There are '+str(len(dfRBPpeaks[dfRBPpeaks.Strand == '+']))+' and '+str(len(dfRBPpeaks[dfRBPpeaks.Strand == '-']))+' binding site on the forward and reverse strand respectively. There are '+str(len(set(dfRBPpeaks['RBP'])))+' different RBPs detected on '+str(len(set(dfRBPpeaks['Sample_Tissue_cellLine'])))+' sample/tissue/cell lines and are '+'\n\t- '.join(list(set(dfRBPpeaks['Sample_Tissue_cellLine'])))+'\n These RBP were dected throught: '+'\n\t- '.join(list(set(dfRBPpeaks['Method']))))
# Out:
# There are 1428928 and 1358475 binding site on the forward and reverse strand respectively. There are 46 different RBPs detected on 35 sample/tissue/cell lines and are mESC-derived_neurona
# 	- C2C12
# 	- N2A
# 	- Muscle
# 	- Testis
# 	- Embryo
# 	- Mouse_embryonic_fibr
# 	- Myoblast
# 	- Keratinocytes
# 	- N2A,SRRM4_KD
# 	- Mandibular
# 	- Quadriceps
# 	- Intestinal_epithelia
# 	- Cortex
# 	- CD-1
# 	- MEF,Mbnl1/2_KO
# 	- MEF
# 	- B cell
# 	- Heart
# 	- mESC
# 	- T cell
# 	- Intestinal
# 	- Embryonic stem
# 	- P19
# 	- Fibroblast
# 	- Embryonal
# 	- V6.5
# 	- NSC-34
# 	- CD4 T cell
# 	- MEL
# 	- Dendritic cell
# 	- Macrophage
# 	- Brain
# 	- Mouse_mandibular_MEP
# 	- Embryonic_stem_cells
#  These RBP were dected throught: iCLIP,PureCLIP
# 	- iCLIP,Piranha_0.01
# 	- iCLIP,CIMS
# 	- PAR-CLIP,PARalyzer
# 	- HITS-CLIP,CIMS
# 	- Fr-iCLIP,PureCLIP
# 	- BrdU-CLIP,CTK
# 	- Fr-iCLIP,Piranha_0.01
# 	- PAR-CLIP,Piranha_0.01
# 	- HITS-CLIP,CTK
# 	- BrdU-CLIP,Piranha_0.01
# ...

# %% [markdown]
# MEL -> Mouse erythroleukemia cell line
#
# NSC-34 -> hybrid cell line produced by the fusion of MN from the spinal cords of mouse embryos with mouse neuroblastoma cells N18TG2 (Cashman et al., 1992).
#
# v6.5 -> mouse embryonic stem cell line was established from cells derived from the inner cell mass (ICM) of a 3.5 day old mouse embryo from a C57BL/6 X 129/sv cross and has been used successfully in producing germline transmitting chimeras. The v6.5 mouse ES cell lines is the parent strain from which the DGCR8 -/- knockout cell line (NBA1-19349) is derived.
#
# P19 -> pluripotent embryonal carcinoma able to grow continuously in serum-supplemented media
#
# mESCs -> Mouse embryonic stem cells were first isolated and propagated in culture in 1981. mESCs are typically isolated from blastocysts from the inner cell mass of 3.5-day-old embryos and have the potential to generate every cell type found in the body.
#
# MEF -> mouse embryonic fibroblast
#
# CD-1 -> CD1 (cluster of differentiation 1) is a family of glycoproteins expressed on the surface of various human antigen-presenting cells. They are related to the class I MHC molecules, and are involved in the presentation of lipid antigens to T cells. However their precise function is unknown. Mice lack the group 1 CD1 molecules, and instead have 2 copies of CD1d.
#
# N2a -> mouse neural crest-derived cell line that has been extensively used to study neuronal differentiation, axonal growth and signaling pathways

# %% [markdown]
# # Dmel

# %%
directory = '/home/anais/Documents/Projet/G4RBPevo/data/POSTARTexcludedHuman/'
inputfile = directory + '/drosophila_melanogaster.bed'
dfRBPpeaks = pd.read_csv(inputfile, sep='\t', names=['Chromosome', 'Start_BS', 'End_BS', 'Id_BS', 'Strand', 'RBP', 'Method', 'Sample_Tissue_cellLine', 'Accession'])
dfRBPpeaks
# Out:
#        Chromosome  Start_BS   End_BS  \
# 0           chr2L      9854     9959
# 1           chr2L      9854     9959
# 2           chr2L      9860     9976
# 3           chr2L      9860     9976
# 4           chr2L      9875     9979
# ...           ...       ...      ...
# 546462       chrY   3572676  3572694
# 546463       chrY   3572676  3572694
# 546464       chrY   3572676  3572694
# 546465       chrY   3572676  3572694
# 546466       chrY   3609316  3609317
#
#                                            Id_BS Strand    RBP  \
# 0       fly_RBP_CLIPdb_PAR-CLIP_PARalyzer_174442      -   ORBF
# 1       fly_RBP_CLIPdb_PAR-CLIP_PARalyzer_383017      -   ORBF
# 2       fly_RBP_CLIPdb_PAR-CLIP_PARalyzer_307899      -  ORB2B
# 3        fly_RBP_CLIPdb_PAR-CLIP_PARalyzer_99324      -  ORB2B
# 4       fly_RBP_CLIPdb_PAR-CLIP_PARalyzer_133293      -   ORBF
# ...                                          ...    ...    ...
# 546462  fly_RBP_CLIPdb_PAR-CLIP_PARalyzer_202588      +    PEP
# ...

# %%
print('There are '+str(len(dfRBPpeaks[dfRBPpeaks.Strand == '+']))+' and '+str(len(dfRBPpeaks[dfRBPpeaks.Strand == '-']))+' binding site on the forward and reverse strand respectively. There are '+str(len(set(dfRBPpeaks['RBP'])))+' different RBPs detected on '+str(len(set(dfRBPpeaks['Sample_Tissue_cellLine'])))+' sample/tissue/cell lines and are '+'\n\t- '.join(list(set(dfRBPpeaks['Sample_Tissue_cellLine'])))+'\n These RBP were dected throught: '+'\n\t- '.join(list(set(dfRBPpeaks['Method']))))
# Out:
# There are 262360 and 284107 binding site on the forward and reverse strand respectively. There are 7 different RBPs detected on 2 sample/tissue/cell lines and are S2
# 	- Embryo
#  These RBP were dected throught: iCLIP,PureCLIP
# 	- iCLIP,Piranha_0.01
# 	- HITS-CLIP,Piranha_0.01
# 	- iCLIP,CIMS
# 	- HITS-CLIP,CIMS
# 	- PAR-CLIP,Piranha_0.01
# 	- HITS-CLIP,CTK
# 	- PAR-CLIP,PARalyzer
# 	- PAR-CLIP,MiClip

# %% [markdown]
# # Cele

# %%
directory = '/home/anais/Documents/Projet/G4RBPevo/data/POSTARTexcludedHuman/'
inputfile = directory + '/caenorhabditis_elegans.bed'
dfRBPpeaks = pd.read_csv(inputfile, sep='\t', names=['Chromosome', 'Start_BS', 'End_BS', 'Id_BS', 'Strand', 'RBP', 'Method', 'Sample_Tissue_cellLine', 'Accession'])
dfRBPpeaks
# Out:
#        Chromosome  Start_BS    End_BS                           Id_BS Strand  \
# 0            chrI      3746      3778  worm_RBP_CLIPdb_PAR-CLIP_67224      -
# 1            chrI      3778      3779    worm_RBP_CLIPdb_iCLIP_222341      -
# 2            chrI      3800      3820    worm_RBP_CLIPdb_iCLIP_218226      -
# 3            chrI      3800      3820    worm_RBP_CLIPdb_iCLIP_237847      -
# 4            chrI      3800      3820    worm_RBP_CLIPdb_iCLIP_426926      -
# ...           ...       ...       ...                             ...    ...
# 539128       chrX  17718623  17718624    worm_RBP_CLIPdb_iCLIP_216435      +
# 539129       chrX  17718656  17718657    worm_RBP_CLIPdb_iCLIP_172828      +
# 539130       chrX  17718667  17718668     worm_RBP_CLIPdb_iCLIP_75154      +
# 539131       chrX  17718670  17718671    worm_RBP_CLIPdb_iCLIP_421075      +
# 539132       chrX  17718690  17718691    worm_RBP_CLIPdb_iCLIP_312675      +
#
# ...

# %%
print('There are '+str(len(dfRBPpeaks[dfRBPpeaks.Strand == '+']))+' and '+str(len(dfRBPpeaks[dfRBPpeaks.Strand == '-']))+' binding site on the forward and reverse strand respectively. There are '+str(len(set(dfRBPpeaks['RBP'])))+' different RBPs detected on '+str(len(set(dfRBPpeaks['Sample_Tissue_cellLine'])))+' sample/tissue/cell lines and are '+'\n\t- '.join(list(set(dfRBPpeaks['Sample_Tissue_cellLine'])))+'\n These RBP were dected throught: '+'\n\t- '.join(list(set(dfRBPpeaks['Method']))))
# Out:
# There are 273356 and 265777 binding site on the forward and reverse strand respectively. There are 6 different RBPs detected on 6 sample/tissue/cell lines and are young_adult_whole_worm
# 	- Young_adult_whole_worm
# 	- whole_organism
# 	- Germline_stem_cell
# 	- nematode_whole_worm
# 	- Whole
#  These RBP were dected throught: iCLIP,PureCLIP
# 	- iCLIP,Piranha_0.01
# 	- HITS-CLIP,Piranha_0.01
# 	- iCLIP,CIMS
# 	- HITS-CLIP,CIMS
# 	- PAR-CLIP,Piranha_0.01
# 	- PAR-CLIP,PARalyzer
# 	- PAR-CLIP,MiClip

# %% [markdown]
# # Atha

# %%
directory = '/home/anais/Documents/Projet/G4RBPevo/data/POSTARTexcludedHuman/'
inputfile = directory + '/arabidopsis_thaliana.bed'
dfRBPpeaks = pd.read_csv(inputfile, sep='\t', names=['Chromosome', 'Start_BS', 'End_BS', 'Id_BS', 'Strand', 'RBP', 'Method', 'Sample_Tissue_cellLine', 'Accession'])
dfRBPpeaks
# Out:
#        Chromosome  Start_BS  End_BS                                Id_BS  \
# 0            Chr1      6936    6937   arabidopsis_RBP_CLIPdb_iCLIP_58868
# 1            Chr1     28718   28719   arabidopsis_RBP_CLIPdb_iCLIP_11582
# 2            Chr1     31254   31255    arabidopsis_RBP_CLIPdb_iCLIP_1554
# 3            Chr1     31257   31258      Arabidopsis_RBP_POSTAR2update_1
# 4            Chr1     31287   31288      Arabidopsis_RBP_POSTAR2update_2
# ...           ...       ...     ...                                  ...
# 200332      ChrPt    119439  119440  arabidopsis_RBP_CLIPdb_iCLIP_134662
# 200333      ChrPt    119758  119759  arabidopsis_RBP_CLIPdb_iCLIP_134663
# 200334      ChrPt    120160  120161  arabidopsis_RBP_CLIPdb_iCLIP_134664
# 200335      ChrPt    121518  121519  arabidopsis_RBP_CLIPdb_iCLIP_134665
# 200336      ChrPt    121687  121688  arabidopsis_RBP_CLIPdb_iCLIP_134666
#
#        Strand   RBP          Method Sample_Tissue_cellLine  \
# ...

# %%
print('There are '+str(len(dfRBPpeaks[dfRBPpeaks.Strand == '+']))+' and '+str(len(dfRBPpeaks[dfRBPpeaks.Strand == '-']))+' binding site on the forward and reverse strand respectively. There are '+str(len(set(dfRBPpeaks['RBP'])))+' different RBPs detected on '+str(len(set(dfRBPpeaks['Sample_Tissue_cellLine'])))+' sample/tissue/cell lines and are '+'\n\t- '.join(list(set(dfRBPpeaks['Sample_Tissue_cellLine'])))+'\n These RBP were dected throught: '+'\n\t- '.join(list(set(dfRBPpeaks['Method']))))
# Out:
# There are 100003 and 100334 binding site on the forward and reverse strand respectively. There are 5 different RBPs detected on 3 sample/tissue/cell lines and are Seedling
# 	- aerial_tissue
# 	- Aerial_tissue
#  These RBP were dected throught: iCLIP,PureCLIP
# 	- iCLIP,Piranha_0.01
# 	- iCLIP,CIMS
# 	- HITS-CLIP,CIMS
# 	- HITS-CLIP,CTK
# 	- HITS-CLIP,Piranha_0.01

# %% [markdown]
# # Drer

# %%
directory = '/home/anais/Documents/Projet/G4RBPevo/data/POSTARTexcludedHuman/'
inputfile = directory + '/danio_rerio.bed'
dfRBPpeaks = pd.read_csv(inputfile, sep='\t', names=['Chromosome', 'Start_BS', 'End_BS', 'Id_BS', 'Strand', 'RBP', 'Method', 'Sample_Tissue_cellLine', 'Accession'])
dfRBPpeaks
# Out:
#       Chromosome  Start_BS  End_BS                        Id_BS Strand  \
# 0           chr1      6660    6680   Zebrafish_RBP_POSTAR3_9503      -
# 1           chr1      6734    6735  Zebrafish_RBP_POSTAR3_11880      -
# 2           chr1      6737    6738  Zebrafish_RBP_POSTAR3_27208      -
# 3           chr1      6741    6742  Zebrafish_RBP_POSTAR3_35697      -
# 4           chr1    264307  264308  Zebrafish_RBP_POSTAR3_19437      +
# ...          ...       ...     ...                          ...    ...
# 35082      chrMT     16011   16012  Zebrafish_RBP_POSTAR3_35407      +
# 35083      chrMT     16233   16234  Zebrafish_RBP_POSTAR3_19398      +
# 35084      chrMT     16374   16375  Zebrafish_RBP_POSTAR3_42582      +
# 35085      chrMT     16476   16477  Zebrafish_RBP_POSTAR3_26862      +
# 35086      chrMT     16480   16500   Zebrafish_RBP_POSTAR3_7220      +
#
#            RBP              Method Sample_Tissue_cellLine            Accession
# ...

# %%
print('There are '+str(len(dfRBPpeaks[dfRBPpeaks.Strand == '+']))+' and '+str(len(dfRBPpeaks[dfRBPpeaks.Strand == '-']))+' binding site on the forward and reverse strand respectively. There are '+str(len(set(dfRBPpeaks['RBP'])))+' different RBPs detected on '+str(len(set(dfRBPpeaks['Sample_Tissue_cellLine'])))+' sample/tissue/cell lines and are '+'\n\t- '.join(list(set(dfRBPpeaks['Sample_Tissue_cellLine'])))+'\n These RBP were dected throught: '+'\n\t- '.join(list(set(dfRBPpeaks['Method']))))
# Out:
# There are 17379 and 17708 binding site on the forward and reverse strand respectively. There are 2 different RBPs detected on 1 sample/tissue/cell lines and are Embryo
#  These RBP were dected throught: iCLIP,PureCLIP
# 	- iCLIP,Piranha_0.01

# %% [markdown]
# # Check Methods
#
# ###### iCLIP
