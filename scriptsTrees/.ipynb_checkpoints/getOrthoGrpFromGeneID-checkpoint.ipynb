# %%
import os
# import separateTree
import pandas as pd
import networkx as nx
import seaborn as sns
from pprint import pprint
import matplotlib.pyplot as plt

# %%
dicoSp = {'pan_troglodytes' : 'Eukaryota', 'homo_sapiens' : 'Eukaryota', 'pongo_abelii' : 'Eukaryota', 'mus_musculus' : 'Eukaryota', 'monodelphis_domestica' : 'Eukaryota', 'ornithorhynchus_anatinus' : 'Eukaryota', 'anolis_carolinensis' : 'Eukaryota', 'gallus_gallus' : 'Eukaryota', 'danio_rerio' : 'Eukaryota', 'gasterosteus_aculeatus' : 'Eukaryota', 'drosophila_melanogaster' : 'Eukaryota', 'apis_mellifera' : 'Eukaryota', 'caenorhabditis_elegans' : 'Eukaryota', 'neurospora_crassa' : 'Eukaryota', 'aspergillus_nidulans' : 'Eukaryota', 'saccharomyces_cerevisiae' : 'Eukaryota', 'schizosaccharomyces_pombe' : 'Eukaryota', 'dictyostelium_discoideum' : 'Eukaryota', 'arabidopsis_thaliana' : 'Eukaryota', 'vitis_vinifera' : 'Eukaryota', 'solanum_lycopersicum' : 'Eukaryota', 'oryza_sativa' : 'Eukaryota', 'physcomitrella_patens' : 'Eukaryota', 'chlamydomonas_reinhardtii' : 'Eukaryota', 'leishmania_major' : 'Eukaryota', 'methanosarcina_acetivorans_c2a' : 'Archaea', 'halobacterium_salinarum_r1' : 'Archaea', 'hyperthermus_butylicus_dsm_5456' : 'Archaea', 'archaeoglobus_fulgidus_dsm_4304' : 'Archaea', 'methanobrevibacter_smithii_atcc_35061' : 'Archaea', 'pyrococcus_horikoshii_ot3' : 'Archaea', 'thermoplasma_acidophilum_dsm_1728' : 'Archaea', 'sulfolobus_solfataricus_p2' : 'Archaea', 'pyrobaculum_aerophilum_str_im2' : 'Archaea', 'nanoarchaeum_equitans_kin4_m' : 'Archaea', 'candidatus_korarchaeum_cryptofilum_opf8' : 'Archaea', 'cenarchaeum_symbiosum_a' : 'Archaea', 'aquifex_aeolicus_vf5' : 'Bacteria', 'mycoplasma_pneumoniae_m129' : 'Bacteria', 'staphylococcus_aureus_subsp_aureus_n315' : 'Bacteria', 'bacillus_subtilis_subsp_subtilis_str_168' : 'Bacteria', 'enterococcus_faecalis_v583' : 'Bacteria', 'streptococcus_pneumoniae_tigr4' : 'Bacteria', 'chloroflexus_aurantiacus_j_10_fl' : 'Bacteria', 'mycobacterium_tuberculosis_h37rv' : 'Bacteria', 'thermus_thermophilus_hb8' : 'Bacteria', 'chlamydia_trachomatis_d_uw_3_cx' : 'Bacteria', 'borrelia_burgdorferi_b31' : 'Bacteria', 'campylobacter_jejuni_subsp_jejuni_nctc_11168_atcc_700819' : 'Bacteria', 'myxococcus_xanthus_dk_1622' : 'Bacteria', 'geobacter_sulfurreducens_pca' : 'Bacteria', 'wolbachia_endosymbiont_of_drosophila_melanogaster' : 'Bacteria', 'anaplasma_phagocytophilum_str_hz' : 'Bacteria', 'brucella_abortus_bv_1_str_9_941' : 'Bacteria', 'neisseria_meningitidis_z2491' : 'Bacteria', 'legionella_pneumophila_str_paris' : 'Bacteria', 'francisella_tularensis_subsp_tularensis_schu_s4' : 'Bacteria', 'vibrio_cholerae_o1_biovar_el_tor_str_n16961' : 'Bacteria', 'haemophilus_influenzae_rd_kw20' : 'Bacteria', 'yersinia_pestis_biovar_microtus_str_91001' : 'Bacteria', 'escherichia_coli_str_k_12_substr_mg1655' : 'Bacteria'}
spList = ['anaplasma_phagocytophilum_str_hz', 'leishmania_major', 'anolis_carolinensis',
    'methanobrevibacter_smithii_atcc_35061', 'apis_mellifera', 'methanosarcina_acetivorans_c2a',
    'aquifex_aeolicus_vf5', 'monodelphis_domestica', 'arabidopsis_thaliana', 'mus_musculus',
    'archaeoglobus_fulgidus_dsm_4304', 'mycobacterium_tuberculosis_h37rv',
    'aspergillus_nidulans', 'mycoplasma_pneumoniae_m129', 'bacillus_subtilis_subsp_subtilis_str_168',
    'myxococcus_xanthus_dk_1622', 'borrelia_burgdorferi_b31', 'nanoarchaeum_equitans_kin4_m',
    'brucella_abortus_bv_1_str_9_941', 'neisseria_meningitidis_z2491', 'caenorhabditis_elegans',
    'neurospora_crassa', 'campylobacter_jejuni_subsp_jejuni_nctc_11168_atcc_700819',
    'ornithorhynchus_anatinus', 'candidatus_korarchaeum_cryptofilum_opf8', 'oryza_sativa',
    'cenarchaeum_symbiosum_a', 'pan_troglodytes', 'chlamydia_trachomatis_d_uw_3_cx',
    'physcomitrella_patens', 'chlamydomonas_reinhardtii', 'pongo_abelii',
    'chloroflexus_aurantiacus_j_10_fl', 'pyrobaculum_aerophilum_str_im2', 'danio_rerio',
    'pyrococcus_horikoshii_ot3', 'dictyostelium_discoideum', 'saccharomyces_cerevisiae',
    'drosophila_melanogaster', 'schizosaccharomyces_pombe', 'enterococcus_faecalis_v583',
    'solanum_lycopersicum', 'escherichia_coli_str_k_12_substr_mg1655',
    'staphylococcus_aureus_subsp_aureus_n315', 'francisella_tularensis_subsp_tularensis_schu_s4',
    'streptococcus_pneumoniae_tigr4', 'gallus_gallus', 'sulfolobus_solfataricus_p2',
    'gasterosteus_aculeatus', 'thermoplasma_acidophilum_dsm_1728', 'geobacter_sulfurreducens_pca',
    'thermus_thermophilus_hb8', 'haemophilus_influenzae_rd_kw20',
    'vibrio_cholerae_o1_biovar_el_tor_str_n16961', 'halobacterium_salinarum_r1',
    'vitis_vinifera', 'homo_sapiens', 'wolbachia_endosymbiont_of_drosophila_melanogaster',
    'hyperthermus_butylicus_dsm_5456', 'yersinia_pestis_biovar_microtus_str_91001', 'legionella_pneumophila_str_paris']

# %%
dicoGeneListbySp = {}
for path, dirs, files in os.walk("/home/anais/Documents/Projet/G4Evolution/Homology/"):
    # for each element of the directory to passed
    for filename in files: # for each files
        inputfile = "/home/anais/Documents/Projet/G4Evolution/Homology/" + filename
        if 'txt' in inputfile:
            sp = filename.split('.')[0]
            with open(inputfile) as f:
                content = f.read()
                lines = content.split('\n')
                for l in lines:
                    dicoGeneListbySp[l] = sp

# %% [markdown]
# WAY TO HEAVY to run here, need to find an alt way...

# %%
# filename = "/home/anais/Documents/Projet/G4Evolution/Homology/"

# G = nx.Graph()

# for sp in spList:
#     with open(filename+sp+".tsv") as f: # file opening
#         content = f.read()
#         lines = content.split('\n')
#         for l in lines: # browse all lines
#             if l:
#                 words = l.split('\t')
#                 gene1 = words[0]
#                 gene2 = words[5]
#                 homologyT = words[4]
#                 specie1 = words[2]
#                 specie2 = words[7]
#                 if specie1 in spList and specie2 in spList:
#                     if gene1 not in G:
#                         G.add_node(gene1, specie=specie1)
#                     if gene2 not in G:
#                         G.add_node(gene2, specie=specie2)
#                     G.add_edge(gene1, gene2)

# cc = nx.connected_components(G) #get connex composant

# for familly in cc:
#     famG = nx.Graph(G.subgraph(familly))
#     if "ENSG00000004700" in famG:
#         print(famG)

# %% [markdown]
# # Method 2, start by the human genes and ortho and go through all the others?
# ## Import humans genes

# %%
path = "/home/anais/Documents/Projet/G4Evolution/Homology/"

G = nx.Graph()

with open(path+"homo_sapiens.tsv") as f: # file opening
    content = f.read()
    lines = content.split('\n')
    for l in lines: # browse all lines
        if l:
            if "ENSG00000004700" in l:
                words = l.split('\t')
                gene1 = words[0]
                gene2 = words[5]
                homologyT = words[4]
                specie1 = words[2]
                specie2 = words[7]
                if specie1 in spList and specie2 in spList:
                    if gene1 not in G:
                        G.add_node(gene1, specie=specie1)
                    if gene2 not in G:
                        G.add_node(gene2, specie=specie2)
                    G.add_edge(gene1, gene2)

# %%
pos = nx.spring_layout(G, seed=225)  # Seed for reproducible layout
nx.draw(G, pos)
plt.show()

# %%
pathlengths = []

print("source vertex {target:length, }")
for v in G.nodes():
    spl = dict(nx.single_source_shortest_path_length(G, v))
    print(f"{v} {spl} ")
    for p in spl:
        pathlengths.append(spl[p])

print()
print(f"average shortest path length {sum(pathlengths) / len(pathlengths)}")

# histogram of path lengths
dist = {}
for p in pathlengths:
    if p in dist:
        dist[p] += 1
    else:
        dist[p] = 1

print()
print("length #paths")
verts = dist.keys()
for d in sorted(verts):
    print(f"{d} {dist[d]}")

print(f"radius: {nx.radius(G)}")
print(f"diameter: {nx.diameter(G)}")
print(f"eccentricity: {nx.eccentricity(G)}")
print(f"center: {nx.center(G)}")
print(f"periphery: {nx.periphery(G)}")
print(f"density: {nx.density(G)}")

pos = nx.spring_layout(G, seed=3068)  # Seed layout for reproducibility
nx.draw(G, pos=pos, with_labels=True)
plt.show()
# Out:
# source vertex {target:length, }
# ENSG00000004700 {'ENSG00000004700': 0, 'ENSG00000108469': 1, 'AT1G31360': 1, 'ENSDARG00000007175': 1, 'ENSMUSG00000030243': 1, 'ENSACAG00000017383': 1, 'VIT_02s0087g00070': 1, 'Pp3c5_19440': 1, 'ENSMODG00000017805': 1, 'ENSMODG00000025342': 1, 'ENSGALG00000013174': 1, 'ENSPTRG00000004758': 1, 'GB44346': 1, 'ENSG00000165392': 1, 'Os11g0708600': 1, 'SPAC212.06c': 1, 'ENSG00000160957': 1, 'ENSPPYG00000004352': 1, 'ENSOANG00000021930': 1, 'ENSOANG00000002400': 1, 'WBGene00019334': 1, 'MXAN_4839': 1, 'Solyc08g074600.3': 1, 'SPAC212.11': 1, 'ANIA_05092': 1, 'CHLRE_01g004651v5': 1, 'SPBCPT2R1.08c': 1, 'ENSG00000197299': 1, 'ENSGACG00000001005': 1}
# ENSG00000165392 {'ENSG00000165392': 0, 'ENSG00000004700': 1, 'ENSG00000108469': 2, 'AT1G31360': 2, 'ENSDARG00000007175': 2, 'ENSMUSG00000030243': 2, 'ENSACAG00000017383': 2, 'VIT_02s0087g00070': 2, 'Pp3c5_19440': 2, 'ENSMODG00000017805': 2, 'ENSMODG00000025342': 2, 'ENSGALG00000013174': 2, 'ENSPTRG00000004758': 2, 'GB44346': 2, 'Os11g0708600': 2, 'SPAC212.06c': 2, 'ENSG00000160957': 2, 'ENSPPYG00000004352': 2, 'ENSOANG00000021930': 2, 'ENSOANG00000002400': 2, 'WBGene00019334': 2, 'MXAN_4839': 2, 'Solyc08g074600.3': 2, 'SPAC212.11': 2, 'ANIA_05092': 2, 'CHLRE_01g004651v5': 2, 'SPBCPT2R1.08c': 2, 'ENSG00000197299': 2, 'ENSGACG00000001005': 2}
# ANIA_05092 {'ANIA_05092': 0, 'ENSG00000004700': 1, 'ENSG00000108469': 2, 'AT1G31360': 2, 'ENSDARG00000007175': 2, 'ENSMUSG00000030243': 2, 'ENSACAG00000017383': 2, 'VIT_02s0087g00070': 2, 'Pp3c5_19440': 2, 'ENSMODG00000017805': 2, 'ENSMODG00000025342': 2, 'ENSGALG00000013174': 2, 'ENSPTRG00000004758': 2, 'GB44346': 2, 'ENSG00000165392': 2, 'Os11g0708600': 2, 'SPAC212.06c': 2, 'ENSG00000160957': 2, 'ENSPPYG00000004352': 2, 'ENSOANG00000021930': 2, 'ENSOANG00000002400': 2, 'WBGene00019334': 2, 'MXAN_4839': 2, 'Solyc08g074600.3': 2, 'SPAC212.11': 2, 'CHLRE_01g004651v5': 2, 'SPBCPT2R1.08c': 2, 'ENSG00000197299': 2, 'ENSGACG00000001005': 2}
# ENSG00000160957 {'ENSG00000160957': 0, 'ENSG00000004700': 1, 'ENSG00000108469': 2, 'AT1G31360': 2, 'ENSDARG00000007175': 2, 'ENSMUSG00000030243': 2, 'ENSACAG00000017383': 2, 'VIT_02s0087g00070': 2, 'Pp3c5_19440': 2, 'ENSMODG00000017805': 2, 'ENSMODG00000025342': 2, 'ENSGALG00000013174': 2, 'ENSPTRG00000004758': 2, 'GB44346': 2, 'ENSG00000165392': 2, 'Os11g0708600': 2, 'SPAC212.06c': 2, 'ENSPPYG00000004352': 2, 'ENSOANG00000021930': 2, 'ENSOANG00000002400': 2, 'WBGene00019334': 2, 'MXAN_4839': 2, 'Solyc08g074600.3': 2, 'SPAC212.11': 2, 'ANIA_05092': 2, 'CHLRE_01g004651v5': 2, 'SPBCPT2R1.08c': 2, 'ENSG00000197299': 2, 'ENSGACG00000001005': 2}
# MXAN_4839 {'MXAN_4839': 0, 'ENSG00000004700': 1, 'ENSG00000108469': 2, 'AT1G31360': 2, 'ENSDARG00000007175': 2, 'ENSMUSG00000030243': 2, 'ENSACAG00000017383': 2, 'VIT_02s0087g00070': 2, 'Pp3c5_19440': 2, 'ENSMODG00000017805': 2, 'ENSMODG00000025342': 2, 'ENSGALG00000013174': 2, 'ENSPTRG00000004758': 2, 'GB44346': 2, 'ENSG00000165392': 2, 'Os11g0708600': 2, 'SPAC212.06c': 2, 'ENSG00000160957': 2, 'ENSPPYG00000004352': 2, 'ENSOANG00000021930': 2, 'ENSOANG00000002400': 2, 'WBGene00019334': 2, 'Solyc08g074600.3': 2, 'SPAC212.11': 2, 'ANIA_05092': 2, 'CHLRE_01g004651v5': 2, 'SPBCPT2R1.08c': 2, 'ENSG00000197299': 2, 'ENSGACG00000001005': 2}
# ENSG00000197299 {'ENSG00000197299': 0, 'ENSG00000004700': 1, 'ENSG00000108469': 2, 'AT1G31360': 2, 'ENSDARG00000007175': 2, 'ENSMUSG00000030243': 2, 'ENSACAG00000017383': 2, 'VIT_02s0087g00070': 2, 'Pp3c5_19440': 2, 'ENSMODG00000017805': 2, 'ENSMODG00000025342': 2, 'ENSGALG00000013174': 2, 'ENSPTRG00000004758': 2, 'GB44346': 2, 'ENSG00000165392': 2, 'Os11g0708600': 2, 'SPAC212.06c': 2, 'ENSG00000160957': 2, 'ENSPPYG00000004352': 2, 'ENSOANG00000021930': 2, 'ENSOANG00000002400': 2, 'WBGene00019334': 2, 'MXAN_4839': 2, 'Solyc08g074600.3': 2, 'SPAC212.11': 2, 'ANIA_05092': 2, 'CHLRE_01g004651v5': 2, 'SPBCPT2R1.08c': 2, 'ENSGACG00000001005': 2}
# ENSG00000108469 {'ENSG00000108469': 0, 'ENSG00000004700': 1, 'AT1G31360': 2, 'ENSDARG00000007175': 2, 'ENSMUSG00000030243': 2, 'ENSACAG00000017383': 2, 'VIT_02s0087g00070': 2, 'Pp3c5_19440': 2, 'ENSMODG00000017805': 2, 'ENSMODG00000025342': 2, 'ENSGALG00000013174': 2, 'ENSPTRG00000004758': 2, 'GB44346': 2, 'ENSG00000165392': 2, 'Os11g0708600': 2, 'SPAC212.06c': 2, 'ENSG00000160957': 2, 'ENSPPYG00000004352': 2, 'ENSOANG00000021930': 2, 'ENSOANG00000002400': 2, 'WBGene00019334': 2, 'MXAN_4839': 2, 'Solyc08g074600.3': 2, 'SPAC212.11': 2, 'ANIA_05092': 2, 'CHLRE_01g004651v5': 2, 'SPBCPT2R1.08c': 2, 'ENSG00000197299': 2, 'ENSGACG00000001005': 2}
# ENSPTRG00000004758 {'ENSPTRG00000004758': 0, 'ENSG00000004700': 1, 'ENSG00000108469': 2, 'AT1G31360': 2, 'ENSDARG00000007175': 2, 'ENSMUSG00000030243': 2, 'ENSACAG00000017383': 2, 'VIT_02s0087g00070': 2, 'Pp3c5_19440': 2, 'ENSMODG00000017805': 2, 'ENSMODG00000025342': 2, 'ENSGALG00000013174': 2, 'GB44346': 2, 'ENSG00000165392': 2, 'Os11g0708600': 2, 'SPAC212.06c': 2, 'ENSG00000160957': 2, 'ENSPPYG00000004352': 2, 'ENSOANG00000021930': 2, 'ENSOANG00000002400': 2, 'WBGene00019334': 2, 'MXAN_4839': 2, 'Solyc08g074600.3': 2, 'SPAC212.11': 2, 'ANIA_05092': 2, 'CHLRE_01g004651v5': 2, 'SPBCPT2R1.08c': 2, 'ENSG00000197299': 2, 'ENSGACG00000001005': 2}
# ENSPPYG00000004352 {'ENSPPYG00000004352': 0, 'ENSG00000004700': 1, 'ENSG00000108469': 2, 'AT1G31360': 2, 'ENSDARG00000007175': 2, 'ENSMUSG00000030243': 2, 'ENSACAG00000017383': 2, 'VIT_02s0087g00070': 2, 'Pp3c5_19440': 2, 'ENSMODG00000017805': 2, 'ENSMODG00000025342': 2, 'ENSGALG00000013174': 2, 'ENSPTRG00000004758': 2, 'GB44346': 2, 'ENSG00000165392': 2, 'Os11g0708600': 2, 'SPAC212.06c': 2, 'ENSG00000160957': 2, 'ENSOANG00000021930': 2, 'ENSOANG00000002400': 2, 'WBGene00019334': 2, 'MXAN_4839': 2, 'Solyc08g074600.3': 2, 'SPAC212.11': 2, 'ANIA_05092': 2, 'CHLRE_01g004651v5': 2, 'SPBCPT2R1.08c': 2, 'ENSG00000197299': 2, 'ENSGACG00000001005': 2}
# ENSMUSG00000030243 {'ENSMUSG00000030243': 0, 'ENSG00000004700': 1, 'ENSG00000108469': 2, 'AT1G31360': 2, 'ENSDARG00000007175': 2, 'ENSACAG00000017383': 2, 'VIT_02s0087g00070': 2, 'Pp3c5_19440': 2, 'ENSMODG00000017805': 2, 'ENSMODG00000025342': 2, 'ENSGALG00000013174': 2, 'ENSPTRG00000004758': 2, 'GB44346': 2, 'ENSG00000165392': 2, 'Os11g0708600': 2, 'SPAC212.06c': 2, 'ENSG00000160957': 2, 'ENSPPYG00000004352': 2, 'ENSOANG00000021930': 2, 'ENSOANG00000002400': 2, 'WBGene00019334': 2, 'MXAN_4839': 2, 'Solyc08g074600.3': 2, 'SPAC212.11': 2, 'ANIA_05092': 2, 'CHLRE_01g004651v5': 2, 'SPBCPT2R1.08c': 2, 'ENSG00000197299': 2, 'ENSGACG00000001005': 2}
# ENSMODG00000025342 {'ENSMODG00000025342': 0, 'ENSG00000004700': 1, 'ENSG00000108469': 2, 'AT1G31360': 2, 'ENSDARG00000007175': 2, 'ENSMUSG00000030243': 2, 'ENSACAG00000017383': 2, 'VIT_02s0087g00070': 2, 'Pp3c5_19440': 2, 'ENSMODG00000017805': 2, 'ENSGALG00000013174': 2, 'ENSPTRG00000004758': 2, 'GB44346': 2, 'ENSG00000165392': 2, 'Os11g0708600': 2, 'SPAC212.06c': 2, 'ENSG00000160957': 2, 'ENSPPYG00000004352': 2, 'ENSOANG00000021930': 2, 'ENSOANG00000002400': 2, 'WBGene00019334': 2, 'MXAN_4839': 2, 'Solyc08g074600.3': 2, 'SPAC212.11': 2, 'ANIA_05092': 2, 'CHLRE_01g004651v5': 2, 'SPBCPT2R1.08c': 2, 'ENSG00000197299': 2, 'ENSGACG00000001005': 2}
# ENSMODG00000017805 {'ENSMODG00000017805': 0, 'ENSG00000004700': 1, 'ENSG00000108469': 2, 'AT1G31360': 2, 'ENSDARG00000007175': 2, 'ENSMUSG00000030243': 2, 'ENSACAG00000017383': 2, 'VIT_02s0087g00070': 2, 'Pp3c5_19440': 2, 'ENSMODG00000025342': 2, 'ENSGALG00000013174': 2, 'ENSPTRG00000004758': 2, 'GB44346': 2, 'ENSG00000165392': 2, 'Os11g0708600': 2, 'SPAC212.06c': 2, 'ENSG00000160957': 2, 'ENSPPYG00000004352': 2, 'ENSOANG00000021930': 2, 'ENSOANG00000002400': 2, 'WBGene00019334': 2, 'MXAN_4839': 2, 'Solyc08g074600.3': 2, 'SPAC212.11': 2, 'ANIA_05092': 2, 'CHLRE_01g004651v5': 2, 'SPBCPT2R1.08c': 2, 'ENSG00000197299': 2, 'ENSGACG00000001005': 2}
# ENSACAG00000017383 {'ENSACAG00000017383': 0, 'ENSG00000004700': 1, 'ENSG00000108469': 2, 'AT1G31360': 2, 'ENSDARG00000007175': 2, 'ENSMUSG00000030243': 2, 'VIT_02s0087g00070': 2, 'Pp3c5_19440': 2, 'ENSMODG00000017805': 2, 'ENSMODG00000025342': 2, 'ENSGALG00000013174': 2, 'ENSPTRG00000004758': 2, 'GB44346': 2, 'ENSG00000165392': 2, 'Os11g0708600': 2, 'SPAC212.06c': 2, 'ENSG00000160957': 2, 'ENSPPYG00000004352': 2, 'ENSOANG00000021930': 2, 'ENSOANG00000002400': 2, 'WBGene00019334': 2, 'MXAN_4839': 2, 'Solyc08g074600.3': 2, 'SPAC212.11': 2, 'ANIA_05092': 2, 'CHLRE_01g004651v5': 2, 'SPBCPT2R1.08c': 2, 'ENSG00000197299': 2, 'ENSGACG00000001005': 2}
# ENSGALG00000013174 {'ENSGALG00000013174': 0, 'ENSG00000004700': 1, 'ENSG00000108469': 2, 'AT1G31360': 2, 'ENSDARG00000007175': 2, 'ENSMUSG00000030243': 2, 'ENSACAG00000017383': 2, 'VIT_02s0087g00070': 2, 'Pp3c5_19440': 2, 'ENSMODG00000017805': 2, 'ENSMODG00000025342': 2, 'ENSPTRG00000004758': 2, 'GB44346': 2, 'ENSG00000165392': 2, 'Os11g0708600': 2, 'SPAC212.06c': 2, 'ENSG00000160957': 2, 'ENSPPYG00000004352': 2, 'ENSOANG00000021930': 2, 'ENSOANG00000002400': 2, 'WBGene00019334': 2, 'MXAN_4839': 2, 'Solyc08g074600.3': 2, 'SPAC212.11': 2, 'ANIA_05092': 2, 'CHLRE_01g004651v5': 2, 'SPBCPT2R1.08c': 2, 'ENSG00000197299': 2, 'ENSGACG00000001005': 2}
# ENSOANG00000021930 {'ENSOANG00000021930': 0, 'ENSG00000004700': 1, 'ENSG00000108469': 2, 'AT1G31360': 2, 'ENSDARG00000007175': 2, 'ENSMUSG00000030243': 2, 'ENSACAG00000017383': 2, 'VIT_02s0087g00070': 2, 'Pp3c5_19440': 2, 'ENSMODG00000017805': 2, 'ENSMODG00000025342': 2, 'ENSGALG00000013174': 2, 'ENSPTRG00000004758': 2, 'GB44346': 2, 'ENSG00000165392': 2, 'Os11g0708600': 2, 'SPAC212.06c': 2, 'ENSG00000160957': 2, 'ENSPPYG00000004352': 2, 'ENSOANG00000002400': 2, 'WBGene00019334': 2, 'MXAN_4839': 2, 'Solyc08g074600.3': 2, 'SPAC212.11': 2, 'ANIA_05092': 2, 'CHLRE_01g004651v5': 2, 'SPBCPT2R1.08c': 2, 'ENSG00000197299': 2, 'ENSGACG00000001005': 2}
# ENSOANG00000002400 {'ENSOANG00000002400': 0, 'ENSG00000004700': 1, 'ENSG00000108469': 2, 'AT1G31360': 2, 'ENSDARG00000007175': 2, 'ENSMUSG00000030243': 2, 'ENSACAG00000017383': 2, 'VIT_02s0087g00070': 2, 'Pp3c5_19440': 2, 'ENSMODG00000017805': 2, 'ENSMODG00000025342': 2, 'ENSGALG00000013174': 2, 'ENSPTRG00000004758': 2, 'GB44346': 2, 'ENSG00000165392': 2, 'Os11g0708600': 2, 'SPAC212.06c': 2, 'ENSG00000160957': 2, 'ENSPPYG00000004352': 2, 'ENSOANG00000021930': 2, 'WBGene00019334': 2, 'MXAN_4839': 2, 'Solyc08g074600.3': 2, 'SPAC212.11': 2, 'ANIA_05092': 2, 'CHLRE_01g004651v5': 2, 'SPBCPT2R1.08c': 2, 'ENSG00000197299': 2, 'ENSGACG00000001005': 2}
# ENSGACG00000001005 {'ENSGACG00000001005': 0, 'ENSG00000004700': 1, 'ENSG00000108469': 2, 'AT1G31360': 2, 'ENSDARG00000007175': 2, 'ENSMUSG00000030243': 2, 'ENSACAG00000017383': 2, 'VIT_02s0087g00070': 2, 'Pp3c5_19440': 2, 'ENSMODG00000017805': 2, 'ENSMODG00000025342': 2, 'ENSGALG00000013174': 2, 'ENSPTRG00000004758': 2, 'GB44346': 2, 'ENSG00000165392': 2, 'Os11g0708600': 2, 'SPAC212.06c': 2, 'ENSG00000160957': 2, 'ENSPPYG00000004352': 2, 'ENSOANG00000021930': 2, 'ENSOANG00000002400': 2, 'WBGene00019334': 2, 'MXAN_4839': 2, 'Solyc08g074600.3': 2, 'SPAC212.11': 2, 'ANIA_05092': 2, 'CHLRE_01g004651v5': 2, 'SPBCPT2R1.08c': 2, 'ENSG00000197299': 2}
# ENSDARG00000007175 {'ENSDARG00000007175': 0, 'ENSG00000004700': 1, 'ENSG00000108469': 2, 'AT1G31360': 2, 'ENSMUSG00000030243': 2, 'ENSACAG00000017383': 2, 'VIT_02s0087g00070': 2, 'Pp3c5_19440': 2, 'ENSMODG00000017805': 2, 'ENSMODG00000025342': 2, 'ENSGALG00000013174': 2, 'ENSPTRG00000004758': 2, 'GB44346': 2, 'ENSG00000165392': 2, 'Os11g0708600': 2, 'SPAC212.06c': 2, 'ENSG00000160957': 2, 'ENSPPYG00000004352': 2, 'ENSOANG00000021930': 2, 'ENSOANG00000002400': 2, 'WBGene00019334': 2, 'MXAN_4839': 2, 'Solyc08g074600.3': 2, 'SPAC212.11': 2, 'ANIA_05092': 2, 'CHLRE_01g004651v5': 2, 'SPBCPT2R1.08c': 2, 'ENSG00000197299': 2, 'ENSGACG00000001005': 2}
# WBGene00019334 {'WBGene00019334': 0, 'ENSG00000004700': 1, 'ENSG00000108469': 2, 'AT1G31360': 2, 'ENSDARG00000007175': 2, 'ENSMUSG00000030243': 2, 'ENSACAG00000017383': 2, 'VIT_02s0087g00070': 2, 'Pp3c5_19440': 2, 'ENSMODG00000017805': 2, 'ENSMODG00000025342': 2, 'ENSGALG00000013174': 2, 'ENSPTRG00000004758': 2, 'GB44346': 2, 'ENSG00000165392': 2, 'Os11g0708600': 2, 'SPAC212.06c': 2, 'ENSG00000160957': 2, 'ENSPPYG00000004352': 2, 'ENSOANG00000021930': 2, 'ENSOANG00000002400': 2, 'MXAN_4839': 2, 'Solyc08g074600.3': 2, 'SPAC212.11': 2, 'ANIA_05092': 2, 'CHLRE_01g004651v5': 2, 'SPBCPT2R1.08c': 2, 'ENSG00000197299': 2, 'ENSGACG00000001005': 2}
# GB44346 {'GB44346': 0, 'ENSG00000004700': 1, 'ENSG00000108469': 2, 'AT1G31360': 2, 'ENSDARG00000007175': 2, 'ENSMUSG00000030243': 2, 'ENSACAG00000017383': 2, 'VIT_02s0087g00070': 2, 'Pp3c5_19440': 2, 'ENSMODG00000017805': 2, 'ENSMODG00000025342': 2, 'ENSGALG00000013174': 2, 'ENSPTRG00000004758': 2, 'ENSG00000165392': 2, 'Os11g0708600': 2, 'SPAC212.06c': 2, 'ENSG00000160957': 2, 'ENSPPYG00000004352': 2, 'ENSOANG00000021930': 2, 'ENSOANG00000002400': 2, 'WBGene00019334': 2, 'MXAN_4839': 2, 'Solyc08g074600.3': 2, 'SPAC212.11': 2, 'ANIA_05092': 2, 'CHLRE_01g004651v5': 2, 'SPBCPT2R1.08c': 2, 'ENSG00000197299': 2, 'ENSGACG00000001005': 2}
# AT1G31360 {'AT1G31360': 0, 'ENSG00000004700': 1, 'ENSG00000108469': 2, 'ENSDARG00000007175': 2, 'ENSMUSG00000030243': 2, 'ENSACAG00000017383': 2, 'VIT_02s0087g00070': 2, 'Pp3c5_19440': 2, 'ENSMODG00000017805': 2, 'ENSMODG00000025342': 2, 'ENSGALG00000013174': 2, 'ENSPTRG00000004758': 2, 'GB44346': 2, 'ENSG00000165392': 2, 'Os11g0708600': 2, 'SPAC212.06c': 2, 'ENSG00000160957': 2, 'ENSPPYG00000004352': 2, 'ENSOANG00000021930': 2, 'ENSOANG00000002400': 2, 'WBGene00019334': 2, 'MXAN_4839': 2, 'Solyc08g074600.3': 2, 'SPAC212.11': 2, 'ANIA_05092': 2, 'CHLRE_01g004651v5': 2, 'SPBCPT2R1.08c': 2, 'ENSG00000197299': 2, 'ENSGACG00000001005': 2}
# Os11g0708600 {'Os11g0708600': 0, 'ENSG00000004700': 1, 'ENSG00000108469': 2, 'AT1G31360': 2, 'ENSDARG00000007175': 2, 'ENSMUSG00000030243': 2, 'ENSACAG00000017383': 2, 'VIT_02s0087g00070': 2, 'Pp3c5_19440': 2, 'ENSMODG00000017805': 2, 'ENSMODG00000025342': 2, 'ENSGALG00000013174': 2, 'ENSPTRG00000004758': 2, 'GB44346': 2, 'ENSG00000165392': 2, 'SPAC212.06c': 2, 'ENSG00000160957': 2, 'ENSPPYG00000004352': 2, 'ENSOANG00000021930': 2, 'ENSOANG00000002400': 2, 'WBGene00019334': 2, 'MXAN_4839': 2, 'Solyc08g074600.3': 2, 'SPAC212.11': 2, 'ANIA_05092': 2, 'CHLRE_01g004651v5': 2, 'SPBCPT2R1.08c': 2, 'ENSG00000197299': 2, 'ENSGACG00000001005': 2}
# Pp3c5_19440 {'Pp3c5_19440': 0, 'ENSG00000004700': 1, 'ENSG00000108469': 2, 'AT1G31360': 2, 'ENSDARG00000007175': 2, 'ENSMUSG00000030243': 2, 'ENSACAG00000017383': 2, 'VIT_02s0087g00070': 2, 'ENSMODG00000017805': 2, 'ENSMODG00000025342': 2, 'ENSGALG00000013174': 2, 'ENSPTRG00000004758': 2, 'GB44346': 2, 'ENSG00000165392': 2, 'Os11g0708600': 2, 'SPAC212.06c': 2, 'ENSG00000160957': 2, 'ENSPPYG00000004352': 2, 'ENSOANG00000021930': 2, 'ENSOANG00000002400': 2, 'WBGene00019334': 2, 'MXAN_4839': 2, 'Solyc08g074600.3': 2, 'SPAC212.11': 2, 'ANIA_05092': 2, 'CHLRE_01g004651v5': 2, 'SPBCPT2R1.08c': 2, 'ENSG00000197299': 2, 'ENSGACG00000001005': 2}
# VIT_02s0087g00070 {'VIT_02s0087g00070': 0, 'ENSG00000004700': 1, 'ENSG00000108469': 2, 'AT1G31360': 2, 'ENSDARG00000007175': 2, 'ENSMUSG00000030243': 2, 'ENSACAG00000017383': 2, 'Pp3c5_19440': 2, 'ENSMODG00000017805': 2, 'ENSMODG00000025342': 2, 'ENSGALG00000013174': 2, 'ENSPTRG00000004758': 2, 'GB44346': 2, 'ENSG00000165392': 2, 'Os11g0708600': 2, 'SPAC212.06c': 2, 'ENSG00000160957': 2, 'ENSPPYG00000004352': 2, 'ENSOANG00000021930': 2, 'ENSOANG00000002400': 2, 'WBGene00019334': 2, 'MXAN_4839': 2, 'Solyc08g074600.3': 2, 'SPAC212.11': 2, 'ANIA_05092': 2, 'CHLRE_01g004651v5': 2, 'SPBCPT2R1.08c': 2, 'ENSG00000197299': 2, 'ENSGACG00000001005': 2}
# Solyc08g074600.3 {'Solyc08g074600.3': 0, 'ENSG00000004700': 1, 'ENSG00000108469': 2, 'AT1G31360': 2, 'ENSDARG00000007175': 2, 'ENSMUSG00000030243': 2, 'ENSACAG00000017383': 2, 'VIT_02s0087g00070': 2, 'Pp3c5_19440': 2, 'ENSMODG00000017805': 2, 'ENSMODG00000025342': 2, 'ENSGALG00000013174': 2, 'ENSPTRG00000004758': 2, 'GB44346': 2, 'ENSG00000165392': 2, 'Os11g0708600': 2, 'SPAC212.06c': 2, 'ENSG00000160957': 2, 'ENSPPYG00000004352': 2, 'ENSOANG00000021930': 2, 'ENSOANG00000002400': 2, 'WBGene00019334': 2, 'MXAN_4839': 2, 'SPAC212.11': 2, 'ANIA_05092': 2, 'CHLRE_01g004651v5': 2, 'SPBCPT2R1.08c': 2, 'ENSG00000197299': 2, 'ENSGACG00000001005': 2}
# SPAC212.06c {'SPAC212.06c': 0, 'ENSG00000004700': 1, 'ENSG00000108469': 2, 'AT1G31360': 2, 'ENSDARG00000007175': 2, 'ENSMUSG00000030243': 2, 'ENSACAG00000017383': 2, 'VIT_02s0087g00070': 2, 'Pp3c5_19440': 2, 'ENSMODG00000017805': 2, 'ENSMODG00000025342': 2, 'ENSGALG00000013174': 2, 'ENSPTRG00000004758': 2, 'GB44346': 2, 'ENSG00000165392': 2, 'Os11g0708600': 2, 'ENSG00000160957': 2, 'ENSPPYG00000004352': 2, 'ENSOANG00000021930': 2, 'ENSOANG00000002400': 2, 'WBGene00019334': 2, 'MXAN_4839': 2, 'Solyc08g074600.3': 2, 'SPAC212.11': 2, 'ANIA_05092': 2, 'CHLRE_01g004651v5': 2, 'SPBCPT2R1.08c': 2, 'ENSG00000197299': 2, 'ENSGACG00000001005': 2}
# SPBCPT2R1.08c {'SPBCPT2R1.08c': 0, 'ENSG00000004700': 1, 'ENSG00000108469': 2, 'AT1G31360': 2, 'ENSDARG00000007175': 2, 'ENSMUSG00000030243': 2, 'ENSACAG00000017383': 2, 'VIT_02s0087g00070': 2, 'Pp3c5_19440': 2, 'ENSMODG00000017805': 2, 'ENSMODG00000025342': 2, 'ENSGALG00000013174': 2, 'ENSPTRG00000004758': 2, 'GB44346': 2, 'ENSG00000165392': 2, 'Os11g0708600': 2, 'SPAC212.06c': 2, 'ENSG00000160957': 2, 'ENSPPYG00000004352': 2, 'ENSOANG00000021930': 2, 'ENSOANG00000002400': 2, 'WBGene00019334': 2, 'MXAN_4839': 2, 'Solyc08g074600.3': 2, 'SPAC212.11': 2, 'ANIA_05092': 2, 'CHLRE_01g004651v5': 2, 'ENSG00000197299': 2, 'ENSGACG00000001005': 2}
# CHLRE_01g004651v5 {'CHLRE_01g004651v5': 0, 'ENSG00000004700': 1, 'ENSG00000108469': 2, 'AT1G31360': 2, 'ENSDARG00000007175': 2, 'ENSMUSG00000030243': 2, 'ENSACAG00000017383': 2, 'VIT_02s0087g00070': 2, 'Pp3c5_19440': 2, 'ENSMODG00000017805': 2, 'ENSMODG00000025342': 2, 'ENSGALG00000013174': 2, 'ENSPTRG00000004758': 2, 'GB44346': 2, 'ENSG00000165392': 2, 'Os11g0708600': 2, 'SPAC212.06c': 2, 'ENSG00000160957': 2, 'ENSPPYG00000004352': 2, 'ENSOANG00000021930': 2, 'ENSOANG00000002400': 2, 'WBGene00019334': 2, 'MXAN_4839': 2, 'Solyc08g074600.3': 2, 'SPAC212.11': 2, 'ANIA_05092': 2, 'SPBCPT2R1.08c': 2, 'ENSG00000197299': 2, 'ENSGACG00000001005': 2}
# SPAC212.11 {'SPAC212.11': 0, 'ENSG00000004700': 1, 'ENSG00000108469': 2, 'AT1G31360': 2, 'ENSDARG00000007175': 2, 'ENSMUSG00000030243': 2, 'ENSACAG00000017383': 2, 'VIT_02s0087g00070': 2, 'Pp3c5_19440': 2, 'ENSMODG00000017805': 2, 'ENSMODG00000025342': 2, 'ENSGALG00000013174': 2, 'ENSPTRG00000004758': 2, 'GB44346': 2, 'ENSG00000165392': 2, 'Os11g0708600': 2, 'SPAC212.06c': 2, 'ENSG00000160957': 2, 'ENSPPYG00000004352': 2, 'ENSOANG00000021930': 2, 'ENSOANG00000002400': 2, 'WBGene00019334': 2, 'MXAN_4839': 2, 'Solyc08g074600.3': 2, 'ANIA_05092': 2, 'CHLRE_01g004651v5': 2, 'SPBCPT2R1.08c': 2, 'ENSG00000197299': 2, 'ENSGACG00000001005': 2}
#
# average shortest path length 1.864447086801427
#
# length #paths
# 0 29
# 1 56
# 2 756
# radius: 1
# diameter: 2
# eccentricity: {'ENSG00000004700': 1, 'ENSG00000165392': 2, 'ANIA_05092': 2, 'ENSG00000160957': 2, 'MXAN_4839': 2, 'ENSG00000197299': 2, 'ENSG00000108469': 2, 'ENSPTRG00000004758': 2, 'ENSPPYG00000004352': 2, 'ENSMUSG00000030243': 2, 'ENSMODG00000025342': 2, 'ENSMODG00000017805': 2, 'ENSACAG00000017383': 2, 'ENSGALG00000013174': 2, 'ENSOANG00000021930': 2, 'ENSOANG00000002400': 2, 'ENSGACG00000001005': 2, 'ENSDARG00000007175': 2, 'WBGene00019334': 2, 'GB44346': 2, 'AT1G31360': 2, 'Os11g0708600': 2, 'Pp3c5_19440': 2, 'VIT_02s0087g00070': 2, 'Solyc08g074600.3': 2, 'SPAC212.06c': 2, 'SPBCPT2R1.08c': 2, 'CHLRE_01g004651v5': 2, 'SPAC212.11': 2}
# center: ['ENSG00000004700']
# periphery: ['ENSG00000165392', 'ANIA_05092', 'ENSG00000160957', 'MXAN_4839', 'ENSG00000197299', 'ENSG00000108469', 'ENSPTRG00000004758', 'ENSPPYG00000004352', 'ENSMUSG00000030243', 'ENSMODG00000025342', 'ENSMODG00000017805', 'ENSACAG00000017383', 'ENSGALG00000013174', 'ENSOANG00000021930', 'ENSOANG00000002400', 'ENSGACG00000001005', 'ENSDARG00000007175', 'WBGene00019334', 'GB44346', 'AT1G31360', 'Os11g0708600', 'Pp3c5_19440', 'VIT_02s0087g00070', 'Solyc08g074600.3', 'SPAC212.06c', 'SPBCPT2R1.08c', 'CHLRE_01g004651v5', 'SPAC212.11']
# density: 0.06896551724137931

# %% [markdown]
# ## Complete the graph

# %%
oldLen = len(G)
newLen = oldLen +1
while newLen != oldLen:
    oldLen = len(G)
    genes = list(G.nodes())
    for g in genes:
        if g in dicoGeneListbySp:
            sp = dicoGeneListbySp[g]
        elif g == 'ENSACAG00000017383':
            sp = 'anolis_carolinensis'
        with open(path+sp+".tsv") as f: # file opening
            content = f.read()
            lines = content.split('\n')
            for l in lines: # browse all lines
                if l:
                    if g in l:
                        words = l.split('\t')
                        gene1 = words[0]
                        gene2 = words[5]
                        homologyT = words[4]
                        specie1 = words[2]
                        specie2 = words[7]
                        if specie1 in spList and specie2 in spList:
                            if gene1 not in G:
                                G.add_node(gene1, specie=specie1)
                            if gene2 not in G:
                                G.add_node(gene2, specie=specie2)
                            G.add_edge(gene1, gene2)
    newLen = len(G)

# %%
newLen
# Out:
# 270

# %%
plt.rcParams['figure.figsize'] = [25, 20]
pos = nx.spring_layout(G, seed=3068)  # Seed layout for reproducibility
nx.draw(G, pos=pos, with_labels=True)
plt.show()

# %%
list(G.nodes)
# Out:
# ['ENSG00000004700',
#  'ENSG00000165392',
#  'ANIA_05092',
#  'ENSG00000160957',
#  'MXAN_4839',
#  'ENSG00000197299',
#  'ENSG00000108469',
#  'ENSPTRG00000004758',
#  'ENSPPYG00000004352',
#  'ENSMUSG00000030243',
#  'ENSMODG00000025342',
#  'ENSMODG00000017805',
#  'ENSACAG00000017383',
#  'ENSGALG00000013174',
#  'ENSOANG00000021930',
#  'ENSOANG00000002400',
#  'ENSGACG00000001005',
#  'ENSDARG00000007175',
#  'WBGene00019334',
#  'GB44346',
#  'AT1G31360',
#  'Os11g0708600',
#  'Pp3c5_19440',
#  'VIT_02s0087g00070',
#  'Solyc08g074600.3',
#  'SPAC212.06c',
#  'SPBCPT2R1.08c',
#  'CHLRE_01g004651v5',
#  'SPAC212.11',
#  'ENSPTRG00000020145',
#  'ENSPPYG00000018494',
#  'ENSMUSG00000031583',
#  'ENSOANG00000005952',
#  'ENSGALG00000040909',
#  'ENSACAG00000003109',
#  'ENSMODG00000018997',
#  'ENSDARG00000098211',
#  'WBGene00006944',
#  'Os07g0681600',
#  'Pp3c12_1610',
#  'CHLRE_12g490150v5',
#  'AT2G26160',
#  'AT1G65770',
#  'AT3G25750',
#  'AT1G57906',
#  'AT4G35733',
#  'AT1G65760',
#  'AT1G44080',
#  'AT2G17690',
#  'AT1G65740',
#  'DDB_G0268512',
#  'BSU19220',
#  'ANIA_02087',
#  'BSU23020',
#  'BAB42575',
#  'Caur_2049',
#  'ANIA_04432',
#  'ENSPTRG00000048119',
#  'ENSPPYG00000018984',
#  'ENSMUSG00000033762',
#  'ENSMODG00000011014',
#  'ENSOANG00000003526',
#  'ENSGALG00000042375',
#  'ENSACAG00000010589',
#  'ENSGACG00000015014',
#  'ENSDARG00000077516',
#  'GB54027',
#  'GB55142',
#  'FBgn0040290',
#  'AT2G24255',
#  'AT2G16300',
#  'AT2G17036',
#  'AT2G24250',
#  'AT2G16290',
#  'AT1G64840',
#  'AT2G17030',
#  'VIT_01s0010g02590',
#  'Pp3c11_4840',
#  'Solyc05g014690.2',
#  'Os04g0486800',
#  'CHLRE_15g634701v5',
#  'LMJF_30_2290',
#  'AT5G27680',
#  'MXAN_1950',
#  'Kcr_0682',
#  'AT5G24040',
#  'ENSOANG00000015844',
#  'ENSPTRG00000007460',
#  'ENSPPYG00000006784',
#  'ENSMUSG00000030528',
#  'ENSMODG00000019449',
#  'ENSOANG00000009316',
#  'ENSGALG00000008256',
#  'ENSACAG00000014275',
#  'ENSDARG00000077089',
#  'ENSGACG00000010863',
#  'GB48074',
#  'FBgn0002906',
#  'WBGene00001865',
#  'SPAC2G11.12',
#  'YMR190C',
#  'NCU08598',
#  'DDB_G0292130',
#  'LMJF_24_1530',
#  'Os11g0672700',
#  'CHLRE_03g178950v5',
#  'VIT_14s0060g01440',
#  'CHLRE_12g502350v5',
#  'Solyc01g100280.3',
#  'AT3G05740',
#  'CHLRE_04g219750v5',
#  'EF_2459',
#  'BAB41909',
#  'EF_1545',
#  'lpp0930',
#  'GSU0898',
#  'VC_0196',
#  'b3822',
#  'NMA2213',
#  'YP_3215',
#  'HI_0728',
#  'MA_4507',
#  'ENSPTRG00000009651',
#  'ENSMUSG00000020752',
#  'ENSMODG00000007532',
#  'ENSGALG00000002424',
#  'ENSACAG00000006875',
#  'ENSGACG00000013287',
#  'FBgn0027375',
#  'GB54665',
#  'GB51984',
#  'WBGene00004322',
#  'ENSPPYG00000008632',
#  'ENSDARG00000059556',
#  'GB48073',
#  'AT1G27880',
#  'AT1G10930',
#  'AT4G35740',
#  'Os04g0433800',
#  'Os05g0150600',
#  'Os02g0780800',
#  'Pp3c2_1760',
#  'Pp3c20_2130',
#  'Pp3c23_17960',
#  'VIT_06s0004g08420',
#  'VIT_14s0060g02350',
#  'VIT_12s0035g00400',
#  'VIT_11s0016g00850',
#  'Solyc01g103960.3',
#  'Solyc01g099483.1',
#  'Solyc02g088423.1',
#  'Solyc01g099460.2',
#  'Solyc07g042015.1',
#  'Solyc07g042010.3',
#  'CHLRE_16g673393v5',
#  'ENSOANG00000030751',
#  'Pp3c12_16100',
#  'Pp3c6_21840',
#  'Pp3c9_25570',
#  'Pp3c9_25400',
#  'Pp3c6_9830',
#  'Pp3c5_19550',
#  'Pp3c12_15970',
#  'CHLRE_16g667900v5',
#  'CHLRE_01g009575v5',
#  'CHLRE_01g009650v5',
#  'CHLRE_10g441300v5',
#  'Pp3c12_12460',
#  'Pp3c10_24550',
#  'Pp3c5_2780',
#  'Pp3c15_4400',
#  'Pp3c15_24790',
#  'Pp3c15_24980',
#  'Pp3c18_3900',
#  'Pp3c22_17873',
#  'Pp3c22_17870',
#  'Pp3c23_13360',
#  'DDB_G0272384',
#  'NCU03337',
#  'Os05g0389000',
#  'VIT_00s0772g00020',
#  'Solyc05g051380.3',
#  'VIT_18s0001g08610',
#  'AT5G57390',
#  'VIT_11s0052g00840',
#  'Os03g0176300',
#  'Solyc04g077490.3',
#  'AT5G10510',
#  'Os03g0770700',
#  'VIT_09s0002g01370',
#  'VIT_04s0023g00950',
#  'Solyc11g010710.2',
#  'Os03g0232200',
#  'AT5G17430',
#  'Os07g0124700',
#  'Os02g0614300',
#  'AT1G51190',
#  'Os06g0658000',
#  'VIT_07s0151g00440',
#  'VIT_06s0004g01800',
#  'Os06g0657500',
#  'AT3G20840',
#  'Solyc11g008560.2',
#  'Os01g0899800',
#  'Os04g0653600',
#  'Solyc11g061750.2',
#  'VIT_00s1291g00010',
#  'Solyc07g018290.3',
#  'AT5G65510',
#  'VIT_04s0023g00970',
#  'Os03g0313100',
#  'Os02g0747600',
#  'Solyc03g123430.3',
#  'AT1G72570',
#  'Solyc02g092050.3',
#  'Os04g0504500',
#  'AT4G37750',
#  'Os11g0295900',
#  'AT4G13040',
#  'VIT_00s0184g00010',
#  'Solyc09g059510.3',
#  'Os02g0499000',
#  'CHLRE_02g100100v5',
#  'CHLRE_03g144424v5',
#  'VIT_01s0026g01690',
#  'Solyc06g066390.2',
#  'Os06g0145700',
#  'Solyc01g096865.1',
#  'Solyc02g030210.3',
#  'AT2G41710',
#  'VIT_08s0007g08580',
#  'Os05g0121600',
#  'Os04g0649100',
#  'Os03g0818800',
#  'Os01g0813300',
#  'Os05g0536250',
#  'Os06g0639200',
#  'Os07g0235800',
#  'Os08g0442400',
#  'Os09g0423800',
#  'Os12g0126300',
#  'Solyc04g049800.3',
#  'Solyc02g064960.3',
#  'Solyc02g093150.3',
#  'Solyc03g044300.3',
#  'Solyc03g117720.3',
#  'Solyc01g096860.2',
#  'Solyc06g068570.3',
#  'Solyc08g076380.2',
#  'Solyc09g007260.3',
#  'Solyc10g084340.2',
#  'Solyc11g072600.2',
#  'Solyc12g010490.2',
#  'VIT_08s0040g03180',
#  'VIT_07s0031g00220',
#  'VIT_06s0004g03590',
#  'VIT_09s0018g01650',
#  'VIT_14s0108g00050',
#  'VIT_13s0019g03550',
#  'VIT_13s0047g00340',
#  'VIT_11s0037g00870',
#  'AT5G60120',
#  'AT5G67180',
#  'AT4G36920',
#  'AT3G54320',
#  'AT3G54990',
#  'AT2G28550',
#  'AT2G39250',
#  'AT1G16060',
#  'AT1G79700']

# %% [markdown]
# ## Idem mais que avec les one2one

# %%
G121 = nx.Graph()

with open(path+"homo_sapiens.tsv") as f: # file opening
    content = f.read()
    lines = content.split('\n')
    for l in lines: # browse all lines
        if l:
            if "ENSG00000004700" in l and 'one2one' in l:
                words = l.split('\t')
                gene1 = words[0]
                gene2 = words[5]
                homologyT = words[4]
                specie1 = words[2]
                specie2 = words[7]
                if specie1 in spList and specie2 in spList:
                    if gene1 not in G121:
                        G121.add_node(gene1, specie=specie1)
                    if gene2 not in G121:
                        G121.add_node(gene2, specie=specie2)
                    G121.add_edge(gene1, gene2)
oldLen = len(G121)
newLen = oldLen +1
while newLen != oldLen:
    oldLen = len(G121)
    genes = list(G121.nodes())
    for g in genes:
        if g in dicoGeneListbySp:
            sp = dicoGeneListbySp[g]
        elif g == 'ENSACAG00000017383':
            sp = 'anolis_carolinensis'
        with open(path+sp+".tsv") as f: # file opening
            content = f.read()
            lines = content.split('\n')
            for l in lines: # browse all lines
                if l:
                    if g in l and 'one2one' in l:
                        words = l.split('\t')
                        gene1 = words[0]
                        gene2 = words[5]
                        homologyT = words[4]
                        specie1 = words[2]
                        specie2 = words[7]
                        if specie1 in spList and specie2 in spList:
                            if gene1 not in G121:
                                G121.add_node(gene1, specie=specie1)
                            if gene2 not in G121:
                                G121.add_node(gene2, specie=specie2)
                            G121.add_edge(gene1, gene2)
    newLen = len(G121)

# %%
plt.rcParams['figure.figsize'] = [25, 20]
pos = nx.spring_layout(G121, seed=3068)  # Seed layout for reproducibility
nx.draw(G121, pos=pos, with_labels=True)
plt.show()

# %%
len(G121)
# Out:
# 16

# %%
list(G121.nodes)
# Out:
# ['ENSG00000004700',
#  'ENSPTRG00000004758',
#  'ENSPPYG00000004352',
#  'ENSMUSG00000030243',
#  'ENSACAG00000017383',
#  'ENSGALG00000013174',
#  'ENSGACG00000001005',
#  'ENSDARG00000007175',
#  'WBGene00019334',
#  'GB44346',
#  'AT1G31360',
#  'Os11g0708600',
#  'Pp3c5_19440',
#  'VIT_02s0087g00070',
#  'Solyc08g074600.3',
#  'CHLRE_01g004651v5']

# %% [markdown]
# # Check group ortho of helicase who are not in my list ortho
#
# This might be due because there not a of species having this gene.

# %%
# listHelicaseHuman = ['ENSG00000005100', 'ENSG00000013573', 'ENSG00000039123', 'ENSG00000064703',
#                       'ENSG00000067048', 'ENSG00000067248', 'ENSG00000067596', 'ENSG00000079785',
#                       'ENSG00000080007', 'ENSG00000085224', 'ENSG00000088205', 'ENSG00000089737',
#                       'ENSG00000089876', 'ENSG00000100201', 'ENSG00000101452', 'ENSG00000105671',
#                       'ENSG00000107201', 'ENSG00000107625', 'ENSG00000108406', 'ENSG00000108654',
#                       'ENSG00000108771', 'ENSG00000109606', 'ENSG00000109832', 'ENSG00000110367',
#                       'ENSG00000111364', 'ENSG00000118197', 'ENSG00000123064', 'ENSG00000123136',
#                       'ENSG00000124228', 'ENSG00000125485', 'ENSG00000132153', 'ENSG00000134815',
#                       'ENSG00000135829', 'ENSG00000136271', 'ENSG00000136492', 'ENSG00000137628',
#                       'ENSG00000140829', 'ENSG00000141543', 'ENSG00000144028', 'ENSG00000145833',
#                       'ENSG00000150990', 'ENSG00000152670', 'ENSG00000156502', 'ENSG00000156976',
#                       'ENSG00000157349', 'ENSG00000161960', 'ENSG00000163214', 'ENSG00000165732',
#                       'ENSG00000168872', 'ENSG00000174243', 'ENSG00000174953', 'ENSG00000178105',
#                       'ENSG00000182810', 'ENSG00000183258', 'ENSG00000184735', 'ENSG00000185163',
#                       'ENSG00000198231', 'ENSG00000198563', 'ENSG00000204351', 'ENSG00000204560',
#                       'ENSG00000213782', 'ENSG00000214826', 'ENSG00000215301', 'ENSG00000278053',
#                       'ENSG00000281763']
listHelicaseHuman = ['ENSG00000067048', 'ENSG00000067596','ENSG00000080007', 'ENSG00000100201', 'ENSG00000108654', 'ENSG00000110367', 'ENSG00000125485', 'ENSG00000140829', 'ENSG00000145833', 'ENSG00000152670', 'ENSG00000163214', 'ENSG00000174243', 'ENSG00000174953','ENSG00000184735', 'ENSG00000215301', 'ENSG00000281763']

# %%
dicoHelicaseOrtho = {}
for sp in spList:
    dicoHelicaseOrtho[sp] = []
for h in listHelicaseHuman:
    print(h)
    Gtmp = nx.Graph()
    listSpGrp = []

    with open(path+"homo_sapiens.tsv") as f: # file opening
        content = f.read()
        lines = content.split('\n')
        for l in lines: # browse all lines
            if l:
                if h in l and 'one2one' in l:
                    words = l.split('\t')
                    gene1 = words[0]
                    gene2 = words[5]
                    homologyT = words[4]
                    specie1 = words[2]
                    specie2 = words[7]
                    if specie1 in spList and specie2 in spList:
                        if gene1 not in Gtmp:
                            Gtmp.add_node(gene1, specie=specie1)
                        if gene2 not in Gtmp:
                            Gtmp.add_node(gene2, specie=specie2)
                        Gtmp.add_edge(gene1, gene2)
    oldLen = len(Gtmp)
    newLen = oldLen +1
    while newLen != oldLen:
        oldLen = len(Gtmp)
        genes = list(Gtmp.nodes())
        for g in genes:
            if g in dicoGeneListbySp:
                sp = dicoGeneListbySp[g]
            elif g == 'ENSACAG00000017383':
                sp = 'anolis_carolinensis'
            with open(path+sp+".tsv") as f: # file opening
                content = f.read()
                lines = content.split('\n')
                for l in lines: # browse all lines
                    if l:
                        if g in l and 'one2one' in l:
                            words = l.split('\t')
                            gene1 = words[0]
                            gene2 = words[5]
                            homologyT = words[4]
                            specie1 = words[2]
                            specie2 = words[7]
                            if specie1 in spList and specie2 in spList:
                                if gene1 not in Gtmp:
                                    Gtmp.add_node(gene1, specie=specie1)
                                if gene2 not in Gtmp:
                                    Gtmp.add_node(gene2, specie=specie2)
                                Gtmp.add_edge(gene1, gene2)
        newLen = len(Gtmp)
        
    for g in Gtmp.nodes():
        if g in dicoGeneListbySp:
            listSpGrp.append(dicoGeneListbySp[g])
            dicoHelicaseOrtho[sp].append(dicoGeneListbySp[g])
        elif g == 'ENSACAG00000017383':
            listSpGrp.append('anolis_carolinensis') 
            dicoHelicaseOrtho[sp].append('anolis_carolinensis')
    print('\t', list(set(listSpGrp)))
# Out:
# ENSG00000067048
# 	 []
# ENSG00000067596
# 	 ['danio_rerio', 'arabidopsis_thaliana', 'dictyostelium_discoideum', 'chlamydomonas_reinhardtii', 'caenorhabditis_elegans', 'gallus_gallus', 'vitis_vinifera', 'drosophila_melanogaster', 'aspergillus_nidulans', 'gasterosteus_aculeatus', 'neurospora_crassa', 'monodelphis_domestica', 'mus_musculus', 'schizosaccharomyces_pombe', 'physcomitrella_patens', 'leishmania_major', 'anolis_carolinensis', 'homo_sapiens', 'pan_troglodytes', 'saccharomyces_cerevisiae']
# ENSG00000080007
# 	 ['homo_sapiens', 'pan_troglodytes']
# ENSG00000100201
# 	 ['neurospora_crassa', 'aspergillus_nidulans', 'schizosaccharomyces_pombe', 'dictyostelium_discoideum', 'homo_sapiens', 'saccharomyces_cerevisiae']
# ENSG00000108654
# 	 ['mus_musculus', 'gallus_gallus', 'homo_sapiens', 'pan_troglodytes']
# ENSG00000110367
# 	 ['gallus_gallus', 'monodelphis_domestica', 'mus_musculus', 'pongo_abelii', 'homo_sapiens', 'pan_troglodytes', 'gasterosteus_aculeatus']
# ENSG00000125485
# 	 ['danio_rerio', 'arabidopsis_thaliana', 'apis_mellifera', 'dictyostelium_discoideum', 'chlamydomonas_reinhardtii', 'gallus_gallus', 'vitis_vinifera', 'drosophila_melanogaster', 'aspergillus_nidulans', 'neurospora_crassa', 'monodelphis_domestica', 'schizosaccharomyces_pombe', 'physcomitrella_patens', 'pongo_abelii', 'leishmania_major', 'oryza_sativa', 'homo_sapiens', 'pan_troglodytes', 'saccharomyces_cerevisiae']
# ENSG00000140829
# 	 ['danio_rerio', 'apis_mellifera', 'dictyostelium_discoideum', 'caenorhabditis_elegans', 'gallus_gallus', 'vitis_vinifera', 'drosophila_melanogaster', 'aspergillus_nidulans', 'gasterosteus_aculeatus', 'neurospora_crassa', 'monodelphis_domestica', 'mus_musculus', 'physcomitrella_patens', 'pongo_abelii', 'leishmania_major', 'oryza_sativa', 'homo_sapiens', 'pan_troglodytes', 'saccharomyces_cerevisiae']
# ENSG00000145833
# 	 ['gallus_gallus', 'danio_rerio', 'apis_mellifera', 'monodelphis_domestica', 'mus_musculus', 'pongo_abelii', 'homo_sapiens', 'pan_troglodytes']
# ENSG00000152670
# 	 ['gallus_gallus', 'danio_rerio', 'drosophila_melanogaster', 'apis_mellifera', 'anolis_carolinensis', 'monodelphis_domestica', 'mus_musculus', 'pongo_abelii', 'homo_sapiens', 'pan_troglodytes', 'saccharomyces_cerevisiae', 'gasterosteus_aculeatus']
# ENSG00000163214
# 	 ['danio_rerio', 'drosophila_melanogaster', 'apis_mellifera', 'anolis_carolinensis', 'monodelphis_domestica', 'pongo_abelii', 'homo_sapiens', 'pan_troglodytes', 'gasterosteus_aculeatus']
# ENSG00000174243
# 	 ['gallus_gallus', 'danio_rerio', 'drosophila_melanogaster', 'neurospora_crassa', 'oryza_sativa', 'aspergillus_nidulans', 'apis_mellifera', 'anolis_carolinensis', 'schizosaccharomyces_pombe', 'mus_musculus', 'dictyostelium_discoideum', 'homo_sapiens', 'pongo_abelii', 'chlamydomonas_reinhardtii', 'saccharomyces_cerevisiae', 'caenorhabditis_elegans', 'gasterosteus_aculeatus']
# ENSG00000174953
# 	 ['gallus_gallus', 'vitis_vinifera', 'danio_rerio', 'drosophila_melanogaster', 'apis_mellifera', 'anolis_carolinensis', 'monodelphis_domestica', 'mus_musculus', 'solanum_lycopersicum', 'pongo_abelii', 'homo_sapiens', 'leishmania_major', 'pan_troglodytes', 'chlamydomonas_reinhardtii', 'gasterosteus_aculeatus']
# ENSG00000184735
# 	 []
# ENSG00000215301
# 	 []
# ENSG00000281763
# 	 []

# %%
for sp in dicoHelicaseOrtho:
    dicoHelicaseOrtho[sp] = len(list(set(dicoHelicaseOrtho[sp])))
dicoHelicaseOrtho
# Out:
# {'anaplasma_phagocytophilum_str_hz': 0,
#  'leishmania_major': 24,
#  'anolis_carolinensis': 0,
#  'methanobrevibacter_smithii_atcc_35061': 0,
#  'apis_mellifera': 8,
#  'methanosarcina_acetivorans_c2a': 0,
#  'aquifex_aeolicus_vf5': 0,
#  'monodelphis_domestica': 0,
#  'arabidopsis_thaliana': 19,
#  'mus_musculus': 0,
#  'archaeoglobus_fulgidus_dsm_4304': 0,
#  'mycobacterium_tuberculosis_h37rv': 0,
#  'aspergillus_nidulans': 0,
#  'mycoplasma_pneumoniae_m129': 0,
#  'bacillus_subtilis_subsp_subtilis_str_168': 0,
#  'myxococcus_xanthus_dk_1622': 0,
#  'borrelia_burgdorferi_b31': 0,
#  'nanoarchaeum_equitans_kin4_m': 0,
#  'brucella_abortus_bv_1_str_9_941': 0,
#  'neisseria_meningitidis_z2491': 0,
#  'caenorhabditis_elegans': 0,
#  'neurospora_crassa': 0,
#  'campylobacter_jejuni_subsp_jejuni_nctc_11168_atcc_700819': 0,
#  'ornithorhynchus_anatinus': 0,
#  'candidatus_korarchaeum_cryptofilum_opf8': 0,
#  'oryza_sativa': 0,
#  'cenarchaeum_symbiosum_a': 0,
#  'pan_troglodytes': 2,
#  'chlamydia_trachomatis_d_uw_3_cx': 0,
#  'physcomitrella_patens': 0,
#  'chlamydomonas_reinhardtii': 0,
#  'pongo_abelii': 0,
#  'chloroflexus_aurantiacus_j_10_fl': 0,
#  'pyrobaculum_aerophilum_str_im2': 0,
#  'danio_rerio': 0,
#  'pyrococcus_horikoshii_ot3': 0,
#  'dictyostelium_discoideum': 6,
#  'saccharomyces_cerevisiae': 19,
#  'drosophila_melanogaster': 9,
#  'schizosaccharomyces_pombe': 0,
#  'enterococcus_faecalis_v583': 0,
#  'solanum_lycopersicum': 0,
#  'escherichia_coli_str_k_12_substr_mg1655': 0,
#  'staphylococcus_aureus_subsp_aureus_n315': 0,
#  'francisella_tularensis_subsp_tularensis_schu_s4': 0,
#  'streptococcus_pneumoniae_tigr4': 0,
#  'gallus_gallus': 4,
#  'sulfolobus_solfataricus_p2': 0,
#  'gasterosteus_aculeatus': 7,
#  'thermoplasma_acidophilum_dsm_1728': 0,
#  'geobacter_sulfurreducens_pca': 0,
#  'thermus_thermophilus_hb8': 0,
#  'haemophilus_influenzae_rd_kw20': 0,
#  'vibrio_cholerae_o1_biovar_el_tor_str_n16961': 0,
#  'halobacterium_salinarum_r1': 0,
#  'vitis_vinifera': 0,
#  'homo_sapiens': 0,
#  'wolbachia_endosymbiont_of_drosophila_melanogaster': 0,
#  'hyperthermus_butylicus_dsm_5456': 0,
#  'yersinia_pestis_biovar_microtus_str_91001': 0,
#  'legionella_pneumophila_str_paris': 0}

# %%
len(listHelicaseHuman)
# Out:
# 16
